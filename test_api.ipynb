# %%
import pandas as pd
import requests
import json

pd.set_option('display.max_columns', None)

# %%
url = "https://api.pluggy.ai/auth"

payload = {
    "clientId": "e3092229-0226-4439-b5b5-535a16dfeb42",
    "clientSecret": "TnzAyRxru9rTdoLOjQIePsoCTPJsAnPwXZFGwxAapbw"
}

headers = {
    "accept": "application/json",
    "content-type": "application/json"
}

api_key = requests.post(url,json=payload, headers=headers).json().get("apiKey")

# %%
print(f"API Key: {api_key}")
# Out:
# API Key: eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9..DSeBiOiq6ib81O5GWEHSLa6UWxIbD7hlitSWJvi-OrvKB2AC8MrakYacQtqjAh0QxGLAEZMIOvCFanY2PDZk3R62FLtMjYAM7uTH5PlAoH5kaF8n6GPyGFYMc1GK9gIDNDZdxmHH59wXDDLAYNsiAM2l29CHuoU_5Gy1u47Ef1GD48qaqCPS68vH40K-ZsRP1by_8kg1K7c6OzLr0uZ4bgiRFd0BHOQwnVybdqhmrXitdtGnWG85R_vue6WfZH3ysAJ9SNMz4bajrHrrgPnxZrD9JHTH2V-xS1ovUaxtX4XwNNa6PnQNjUZ2TmrN1JndOTLIMJTTTodiSI5gEgXMKQ

# %%
headers = {
    "X-API-KEY": api_key,
    "Content-Type": "application/json"
}

url = "https://api.pluggy.ai/items"

response = requests.get(url, headers=headers, json=payload,  params={"accountId": "e54de2cd-79ed-4be2-807e-f64bcde933d3"}).json().get("results")
print(f"Response: {response}")
# Out:
# Response: None

# %%
headers = {
    "X-API-KEY": api_key,
    "Content-Type": "application/json"
}

url = "https://api.pluggy.ai/v2/transactions"

response = requests.get(url, headers=headers, json=payload,  params={"accountId": "e54de2cd-79ed-4be2-807e-f64bcde933d3"}).json().get("results")

# %%
print(response)
# Out:
# [{'id': 'd8ae8028-9d5a-49b7-859e-0c29997f7e1a', 'description': 'Aplicação RDB', 'descriptionRaw': 'Aplicação RDB', 'currencyCode': 'BRL', 'amount': -9507.15, 'amountInAccountCurrency': None, 'date': '2026-07-19T15:20:23.854Z', 'category': 'Investments', 'categoryId': '03000000', 'balance': None, 'accountId': 'e54de2cd-79ed-4be2-807e-f64bcde933d3', 'providerCode': None, 'status': 'POSTED', 'paymentData': {'payer': {'accountNumber': None, 'branchNumber': None, 'documentNumber': {'type': 'CPF', 'value': '485.144.928-37'}, 'name': None, 'routingNumber': None, 'routingNumberISPB': None}, 'paymentMethod': 'OTHER', 'reason': None, 'receiver': None, 'receiverReferenceId': None, 'authenticationCode': None, 'referenceNumber': None, 'boletoMetadata': None}, 'type': 'DEBIT', 'operationType': 'RESGATE_APLIC_FINANCEIRA', 'operationTypeAdditionalInfo': None, 'creditCardMetadata': None, 'merchant': None, 'providerId': None, 'order': 0, 'createdAt': '2026-09-07T20:32:23.537Z', 'updatedAt': '2026-09-0
# ...

# %%
transactions_raw = pd.DataFrame([
    {chave: valor for chave, valor in item.items()}
    for item in response
])

transactions_raw.head(5)
# Out:
#                                      id  \
# 0  d8ae8028-9d5a-49b7-859e-0c29997f7e1a
# 1  ede79446-850f-4fc5-bc11-80726139db1f
# 2  df93e824-25ab-4f72-b47e-45248ed1adc7
# 3  8c2e86c6-22f7-4c2b-9068-fc4f7c70a87c
# 4  24f69692-b2ae-4438-96b0-f1f0a2e5cb94
#
#                                          description  \
# 0                                      Aplicação RDB
# 1       Transferência Recebida|Matheus Rocha Cardoso
# 2  Transferência enviada|Amazon Serviços de Varej...
# 3                                        Resgate RDB
# 4                                      Aplicação RDB
#
#                                       descriptionRaw currencyCode    amount  \
# 0                                      Aplicação RDB          BRL  -9507.15
# 1       Transferência Recebida|Matheus Rocha Cardoso          BRL   9507.15
# 2  Transferência enviada|Amazon Serviços de Varej...          BRL   -563.32
# 3                                        Resgate RDB          BRL    563.32
# ...

# %%
transactions = transactions_raw[['id', 'description', 'amount', 'currencyCode', 'date', 'category', 'type', 'status', 'operationType', 'createdAt']]
transactions['bankName'] = 'NuBank'
transactions.head()
# Out:
#                                      id  \
# 0  d8ae8028-9d5a-49b7-859e-0c29997f7e1a
# 1  ede79446-850f-4fc5-bc11-80726139db1f
# 2  df93e824-25ab-4f72-b47e-45248ed1adc7
# 3  8c2e86c6-22f7-4c2b-9068-fc4f7c70a87c
# 4  24f69692-b2ae-4438-96b0-f1f0a2e5cb94
#
#                                          description    amount currencyCode  \
# 0                                      Aplicação RDB  -9507.15          BRL
# 1       Transferência Recebida|Matheus Rocha Cardoso   9507.15          BRL
# 2  Transferência enviada|Amazon Serviços de Varej...   -563.32          BRL
# 3                                        Resgate RDB    563.32          BRL
# 4                                      Aplicação RDB -12509.35          BRL
#
#                        date              category    type  status  \
# 0  2026-07-19T15:20:23.854Z           Investments   DEBIT  POSTED
# 1  2026-07-19T15:19:41.213Z  Same person transfer  CREDIT  POSTED
# ...

# %%
merchants = pd.json_normalize(transactions_raw.loc[~transactions_raw['merchant'].isnull()][['merchant']].drop_duplicates()['merchant'])
merchants = merchants.rename(columns={'category': 'merchantCategory', 'cnae': 'merchantCnae', 'cnpj': 'merchantCnpj', 'id': 'merchantId', 'businessName': 'merchantName'})

merchants.head(5)
# Out:
#    merchantCnae    merchantCnpj merchantCategory  \
# 2       4761001  15436940000103        Bookstore
# 12      9430800  29258597000231         Services
# 14      7490104  25021356000132         Services
# 20      6493000  48041735000190         Services
# 23      8112500  18328750000152          Housing
#
#                                       merchantName
# 2        AMAZON SERVICOS DE VAREJO DO BRASIL LTDA.
# 12                   UNIAO NACIONAL DOS ESTUDANTES
# 14     DLOCAL BRASIL INSTITUICAO DE PAGAMENTO S.A.
# 20  PORTO SEGURO ADMINISTRADORA DE CONSORCIOS LTDA
# 23             CONDOMINIO LIBER BOSQUE DOS BURITIS

# %%
transactions_final = transactions.join(merchants, how='left')
transactions_final.head(5)
# Out:
#                                      id  \
# 0  d8ae8028-9d5a-49b7-859e-0c29997f7e1a
# 1  ede79446-850f-4fc5-bc11-80726139db1f
# 2  df93e824-25ab-4f72-b47e-45248ed1adc7
# 3  8c2e86c6-22f7-4c2b-9068-fc4f7c70a87c
# 4  24f69692-b2ae-4438-96b0-f1f0a2e5cb94
#
#                                          description    amount currencyCode  \
# 0                                      Aplicação RDB  -9507.15          BRL
# 1       Transferência Recebida|Matheus Rocha Cardoso   9507.15          BRL
# 2  Transferência enviada|Amazon Serviços de Varej...   -563.32          BRL
# 3                                        Resgate RDB    563.32          BRL
# 4                                      Aplicação RDB -12509.35          BRL
#
#                        date              category    type  status  \
# 0  2026-07-19T15:20:23.854Z           Investments   DEBIT  POSTED
# 1  2026-07-19T15:19:41.213Z  Same person transfer  CREDIT  POSTED
# ...

# %%
transactions_final.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                48 non-null     str
#  1   description       48 non-null     str
#  2   amount            48 non-null     float64
#  3   currencyCode      48 non-null     str
#  4   date              48 non-null     str
#  5   category          48 non-null     str
#  6   type              48 non-null     str
#  7   status            48 non-null     str
#  8   operationType     48 non-null     str
#  9   createdAt         48 non-null     str
#  10  bankName          48 non-null     str
#  11  merchantCnae      8 non-null      str
#  12  merchantCnpj      8 non-null      str
#  13  merchantCategory  8 non-null      str
#  14  merchantName      8 non-null      str
# dtypes: float64(1), str(14)
# memory usage: 5.8 KB

# %%
transactions.to_csv('transactions.csv', index=False)
